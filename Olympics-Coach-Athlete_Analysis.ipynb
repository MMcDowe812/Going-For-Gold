# %%
#IMPORTING LIBRARIES

import pandas as pd
import numpy as np

# %%
#CREATING FILE PATHS

ath_file_path = "athletes.csv"
coaches_file_path = "coaches.csv"
medals_file_path = "medals_total.csv"
medallists_file_path = "medallists.csv"

# %%
#IMPORTING ORIGINAL CSV DATA

raw_coaches = pd.read_csv(coaches_file_path)
raw_athlets = pd.read_csv(ath_file_path)
raw_medals = pd.read_csv(medals_file_path)
raw_medallists = pd.read_csv(medallists_file_path)

# %%
#viewing raw coaches data

raw_coaches_df = pd.DataFrame(raw_coaches)
#raw_coaches.head(10)
raw_coaches.dtypes

#raw_coaches.dropna()
# Out:
# code             int64
# name            object
# gender          object
# function        object
# category        object
# country_code    object
# country         object
# country_full    object
# disciplines     object
# events          object
# dtype: object

# %%
raw_coaches.columns
raw_coaches['name'] = raw_coaches['name'].astype('string')
raw_coaches.dropna()
# Out:
#         code                  name  gender         function category  \
# 0    1533246        PEDRERO Ofelia  Female            Coach        C
# 1    1535775      RADHI SHENAISHIL    Male       Head Coach        C
# 5    1536328        LOFTUS Adriana  Female            Coach        C
# 7    1538315       GULLA Alejandra  Female  Assistant Coach        C
# 16   1540522      MILANO Guillermo    Male       Head Coach        C
# ..       ...                   ...     ...              ...      ...
# 968  9230017          CAAMANO Juan    Male  Assistant Coach        C
# 969  9230018    TORRESCUSA Ignacio    Male  Assistant Coach        C
# 970  9230020           GJERDE Joar    Male  Assistant Coach        C
# 972  9430008  CICHELLO Juan Manuel    Male  Assistant Coach        C
# 973  9450042  VASSILIADES Emmanuel    Male  Assistant Coach        C
#
#     country_code    country country_full        disciplines events
# 0            MEX     Mexico       Mexico  Artistic Swimming   Team
# 1            IRQ       Iraq         Iraq           Football    Men
# 5            MEX     Mexico       Mexico  Artistic Swimming   Team
# 7            ARG  Argentina    Argentina             Hockey  Women
# 16           ARG  Argentina    Argentina           Handball    Men
# ..           ...        ...          ...                ...    ...
# 968          ESP      Spain        Spain           Handball    Men
# 969          ESP      Spain        Spain           Handball    Men
# 970          NOR     Norway       Norway           Handball  Women
# 972          ITA      Italy        Italy         Volleyball  Women
# 973          GRE     Greece       Greece         Water Polo    Men
#
# [418 rows x 10 columns]

# %%
#CREATING A COPY, NEW DATAFRAME AND CSV FOR FURTHER ANALYSIS

raw_coaches_df.copy()

coaches_filter = raw_coaches.drop(columns=['category'])
coach_info_df = pd.DataFrame(coaches_filter)

coach_info_df.to_csv('coach_info.csv', index=False, encoding='utf8')

# %%
#RAW DATA VIEWING

raw_athlets_df = pd.DataFrame(raw_athlets)
#raw_athlets_df.head(10)
raw_athlets.dropna()
# Out:
#           code                       name          name_short  \
# 2025   1568874            KRISTO Katarina            KRISTO K
# 2977   1891289        AGBEGNENOU Clarisse        AGBEGNENOU C
# 3777   1898335                  REID Emma              REID E
# 4960   1910689            GERCSAK Szabina           GERCSAK S
# 4999   1911113             UNGVARI Attila           UNGVARI A
# 6047   1925346             SCUTTO Assunta            SCUTTO A
# 7177   1938655   PACHECO ESPINOSA Nicolas  PACHECO ESPINOSA N
# 8503   1951567             SAVNER Jessica            SAVNER J
# 8967   1955528  PORTUONDO ISASI Ana Laura  PORTUONDO ISASI AL
# 3777   Gymnastics: Competed at national level until 2010
# 4960   "At school I did some wrestling, football, han...
# 4999                       He wrestled when he was young
# 6047   To win the Olympic Games and the World Champio...
# 7177   Motorsport (drifting): Has competed in the Per...
# 8503   Fencing: In July 2023, she won the Division 1A...
# 8967   She started doing gymnastics, and then played ...
# 9885   Athletics: Competed in her youth in track and ...
# 10425  Played club and high school basketball until h...
#
# [11 rows x 35 columns]

# %%
#CREATING A COPY, NEW DATAFRAME AND CSV FOR FURTHER ANALYSIS 

raw_athlets_df.copy()
raw_athlets_df.dropna()
raw_athlets_df['name'] = raw_athlets_df['name'].astype('string')
raw_athlets_df['coach'] = raw_athlets_df['coach'].astype('string')
raw_athlets_df['birth_date'] = pd.to_datetime(raw_athlets_df['birth_date'])
athletes_filter = raw_athlets_df[["code", "name", "name_tv", "country_code", "country", "country_full", "height", "weight", "disciplines", "events","birth_date", "coach"]]
athletes_filter.dropna()
athletes_df = pd.DataFrame(athletes_filter)

athletes_df.head(10)

#athletes_df.to_csv('athletes_data.csv', index=False, encoding='utf8')
# Out:
#       code                      name                   name_tv country_code  \
# 0  1532872          ALEKSANYAN Artur          Artur ALEKSANYAN          ARM
# 1  1532873            AMOYAN Malkhas            Malkhas AMOYAN          ARM
# 2  1532874           GALSTYAN Slavik           Slavik GALSTYAN          ARM
# 3  1532944         HARUTYUNYAN Arsen         Arsen HARUTYUNYAN          ARM
# 4  1532945           TEVANYAN Vazgen           Vazgen TEVANYAN          ARM
# 5  1532951             ARENAS Lorena             Lorena ARENAS          COL
# 6  1533112           McKENZIE Ashley           Ashley McKENZIE          JAM
# 7  1533136  BASS BITTAYE Gina Mariam  Gina Mariam BASS BITTAYE          GAM
# 8  1533176           CAMARA Ebrahima           Ebrahima CAMARA          GAM
# 9  1533188       RUEDA SANTOS Lizeth       Lizeth RUEDA SANTOS          MEX
#
#     country country_full  height  weight    disciplines  \
# 0   Armenia      Armenia       0     0.0  ['Wrestling']
# 1   Armenia      Armenia       0     0.0  ['Wrestling']
# 2   Armenia      Armenia       0     0.0  ['Wrestling']
# 3   Armenia      Armenia       0     0.0  ['Wrestling']
# 4   Armenia      Armenia       0     0.0  ['Wrestling']
# 5  Colombia     Colombia     162     0.0  ['Athletics']
# 6   Jamaica      Jamaica       0     0.0       ['Judo']
# 7    Gambia       Gambia     161     0.0  ['Athletics']
# 8    Gambia       Gambia     178     0.0  ['Athletics']
# 9    Mexico       Mexico       0     0.0  ['Triathlon']
#
#                                               events birth_date  \
# 0                         ["Men's Greco-Roman 97kg"] 1991-10-21
# 1                         ["Men's Greco-Roman 77kg"] 1999-01-22
# 2                         ["Men's Greco-Roman 67kg"] 1996-12-21
# 3                           ["Men's Freestyle 57kg"] 1999-11-22
# 4                           ["Men's Freestyle 65kg"] 1999-10-27
# 5  ["Women's 20km Race Walk", 'Marathon Race Walk... 1993-09-17
# 6                                     ['Men -60 kg'] 1989-07-17
# 7                   ["Women's 100m", "Women's 200m"] 1995-05-03
# 8                                     ["Men's 100m"] 1996-09-18
# 9                             ["Women's Individual"] 1994-03-07
#
#                                                coach
# 0                    Gevorg Aleksanyan (ARM), father
# 1                                               <NA>
# 2  Personal: Martin Alekhanyan (ARM).<br>National...
# 3                      National: Habetnak Kurghinyan
# 4                National: Habetnak Kurghinyan (ARM)
# 5                     Personal: Brent Vallance (AUS)
# 6          Personal and National: Luke Preston (GBR)
# 7                Personal: Christophe Belliard (FRA)
# 8                Personal: Christophe Belliard (FRA)
# 9                     Personal: Eugenio Chimal (MEX)

# %%
#RAW DATA VIEW AND SAVING TO CSV

raw_medals_df = pd.DataFrame(raw_medals)
raw_medals_df.head(10)

raw_medals_df.to_csv('medal_count.csv', index=False, encoding='utf8')

# %%
#VIEWING RAW DATA

raw_medallists_df = pd.DataFrame(raw_medallists)
raw_medallists_df.head(10)
# Out:
#    medal_date    medal_type  medal_code                 name  gender  \
# 0  2024-07-27    Gold Medal           1      EVENEPOEL Remco    Male
# 1  2024-07-27  Silver Medal           2        GANNA Filippo    Male
# 2  2024-07-27  Bronze Medal           3        van AERT Wout    Male
# 3  2024-07-27    Gold Medal           1          BROWN Grace  Female
# 4  2024-07-27  Silver Medal           2       HENDERSON Anna  Female
# 5  2024-07-27  Bronze Medal           3         DYGERT Chloe  Female
# 6  2024-07-27    Gold Medal           1            OH Sanguk    Male
# 7  2024-07-27  Silver Medal           2        FERJANI Fares    Male
# 8  2024-07-27  Bronze Medal           3         SAMELE Luigi    Male
# 9  2024-07-27    Gold Medal           1  KONG Man Wai Vivian  Female
#
#             country country_code       nationality team team_gender  \
# 0           Belgium          BEL           Belgium  NaN         NaN
# 1             Italy          ITA             Italy  NaN         NaN
# 2           Belgium          BEL           Belgium  NaN         NaN
# 3         Australia          AUS         Australia  NaN         NaN
# 4     Great Britain          GBR     Great Britain  NaN         NaN
# 5     United States          USA     United States  NaN         NaN
# 6             Korea          KOR             Korea  NaN         NaN
# 7           Tunisia          TUN           Tunisia  NaN         NaN
# 8             Italy          ITA             Italy  NaN         NaN
# 9  Hong Kong, China          HKG  Hong Kong, China  NaN         NaN
#
#      discipline                          event event_type  \
# 0  Cycling Road    Men's Individual Time Trial        ATH
# 1  Cycling Road    Men's Individual Time Trial        ATH
# 2  Cycling Road    Men's Individual Time Trial        ATH
# 3  Cycling Road  Women's Individual Time Trial        ATH
# 4  Cycling Road  Women's Individual Time Trial        ATH
# 5  Cycling Road  Women's Individual Time Trial        ATH
# 6       Fencing         Men's Sabre Individual       HATH
# 7       Fencing         Men's Sabre Individual       HATH
# 8       Fencing         Men's Sabre Individual       HATH
# 9       Fencing        Women's Épée Individual       HATH
#
#                                            url_event  birth_date     code
# 0  /en/paris-2024/results/cycling-road/men-s-indi...  2000-01-25  1903136
# 1  /en/paris-2024/results/cycling-road/men-s-indi...  1996-07-25  1923520
# 2  /en/paris-2024/results/cycling-road/men-s-indi...  1994-09-15  1903147
# 3  /en/paris-2024/results/cycling-road/women-s-in...  1992-07-07  1940173
# 4  /en/paris-2024/results/cycling-road/women-s-in...  1998-11-14  1912525
# 5  /en/paris-2024/results/cycling-road/women-s-in...  1997-01-01  1955079
# 6  /en/paris-2024/results/fencing/men-s-sabre-ind...  1996-09-30  1927149
# 7  /en/paris-2024/results/fencing/men-s-sabre-ind...  1997-07-22  1937783
# 8  /en/paris-2024/results/fencing/men-s-sabre-ind...  1987-07-25  1924595
# 9  /en/paris-2024/results/fencing/women-s-epee-in...  1994-02-08  1963262

# %%
raw_medallists_df.dropna()
#raw_medals_df.to_csv('medal_count.csv', index=False, encoding='utf8')
# Out:
#       medal_date    medal_type  medal_code                name  gender  \
# 769   2024-07-27    Gold Medal           1          CHANG Yani  Female
# 770   2024-07-27    Gold Medal           1          CHEN Yiwen  Female
# 771   2024-07-27  Silver Medal           2         BACON Sarah  Female
# 772   2024-07-27  Silver Medal           2        COOK Kassidy  Female
# 773   2024-07-27  Bronze Medal           3       HARPER Yasmin  Female
# ...          ...           ...         ...                 ...     ...
# 2266  2024-08-11  Bronze Medal           3          BOWEN Alex    Male
# 2267  2024-08-11  Bronze Medal           3  DODD Chase William    Male
# 2268  2024-08-11  Bronze Medal           3          DODD Ryder    Male
# 2269  2024-08-11  Bronze Medal           3          IRVING Max    Male
# 2270  2024-08-11  Bronze Medal           3        HOLLAND Drew    Male
#
#             country country_code    nationality                        team  \
# 769           China          CHN          China  People's Republic of China
# 770           China          CHN          China  People's Republic of China
# 771   United States          USA  United States    United States of America
# 772   United States          USA  United States    United States of America
# 773   Great Britain          GBR  Great Britain               Great Britain
# ...             ...          ...            ...                         ...
# 2266  United States          USA  United States    United States of America
# 2267  United States          USA  United States    United States of America
# 2268  United States          USA  United States    United States of America
# 2269  United States          USA  United States    United States of America
# 2270  United States          USA  United States    United States of America
#
#      team_gender  discipline                                event event_type  \
# 769            W      Diving  Women's Synchronised 3m Springboard       TEAM
# 770            W      Diving  Women's Synchronised 3m Springboard       TEAM
# 771            W      Diving  Women's Synchronised 3m Springboard       TEAM
# 772            W      Diving  Women's Synchronised 3m Springboard       TEAM
# 773            W      Diving  Women's Synchronised 3m Springboard       TEAM
# ...          ...         ...                                  ...        ...
# 2266           M  Water Polo                                  Men      HTEAM
# 2267           M  Water Polo                                  Men      HTEAM
# 2268           M  Water Polo                                  Men      HTEAM
# 2269           M  Water Polo                                  Men      HTEAM
# 2270           M  Water Polo                                  Men      HTEAM
#
#                                               url_event  birth_date     code
# 769   /en/paris-2024/results/diving/women-s-synchron...  2001-12-07  1901539
# 770   /en/paris-2024/results/diving/women-s-synchron...  1999-06-15  1901538
# 771   /en/paris-2024/results/diving/women-s-synchron...  1996-09-20  1954159
# 772   /en/paris-2024/results/diving/women-s-synchron...  1995-05-09  1954168
# 773   /en/paris-2024/results/diving/women-s-synchron...  2000-07-28  1900841
# ...                                                 ...         ...      ...
# 2266  /en/paris-2024/results/water-polo/men/fnl-0002...  1993-09-04  1908350
# 2267  /en/paris-2024/results/water-polo/men/fnl-0002...  2003-04-05  1908354
# 2268  /en/paris-2024/results/water-polo/men/fnl-0002...  2006-01-19  1908355
# 2269  /en/paris-2024/results/water-polo/men/fnl-0002...  1995-05-21  1908361
# 2270  /en/paris-2024/results/water-polo/men/fnl-0002...  1995-04-11  1908359
#
# [1498 rows x 16 columns]

# %%
#CREATING A COPY, NEW DATAFRAME AND CSV FOR FURTHER ANALYSIS 

medallists = raw_medallists.copy()
medallists['name'] = medallists['name'].astype('string')
medallists['birth_date'] = pd.to_datetime(medallists['birth_date'])
medallists_filter = medallists[["medal_type", "medal_code", "name", "country", "country_code", "nationality", "discipline", "event", "birth_date", "code"]]
medallists_df = pd.DataFrame(medallists_filter)
medallists_df.head(10)

medallists_df.to_csv('medallist_info.csv', index=False, encoding='utf8')

# %%
medallists_df.dtypes
# Out:
# medal_type              object
# medal_code               int64
# name            string[python]
# country                 object
# country_code            object
# nationality             object
# discipline              object
# event                   object
# birth_date      datetime64[ns]
# code                    object
# dtype: object
