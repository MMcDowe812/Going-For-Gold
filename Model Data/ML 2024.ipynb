# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import numpy as np
from pathlib import Path

# %%
# Create path to file
medallists24 = Path('../medallists.csv')

# %%
# import CSV file
medallists24_df = pd.read_csv(medallists24, encoding="utf-8", low_memory = True)
medallists24_df.head()
# Out:
#   medal_date    medal_type  medal_code             name  gender  \
# 0  7/27/2024    Gold Medal           1  EVENEPOEL Remco    Male
# 1  7/27/2024  Silver Medal           2    GANNA Filippo    Male
# 2  7/27/2024  Bronze Medal           3    van AERT Wout    Male
# 3  7/27/2024    Gold Medal           1      BROWN Grace  Female
# 4  7/27/2024  Silver Medal           2   HENDERSON Anna  Female
#
#          country country_code    nationality team team_gender    discipline  \
# 0        Belgium          BEL        Belgium  NaN         NaN  Cycling Road
# 1          Italy          ITA          Italy  NaN         NaN  Cycling Road
# 2        Belgium          BEL        Belgium  NaN         NaN  Cycling Road
# 3      Australia          AUS      Australia  NaN         NaN  Cycling Road
# 4  Great Britain          GBR  Great Britain  NaN         NaN  Cycling Road
#
#                            event event_type  \
# 0    Men's Individual Time Trial        ATH
# ...

# %%
medallists24_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2271 entries, 0 to 2270
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   medal_date    2271 non-null   object
#  1   medal_type    2271 non-null   object
#  2   medal_code    2271 non-null   int64
#  3   name          2252 non-null   object
#  4   gender        2252 non-null   object
#  5   country       2252 non-null   object
#  6   country_code  2252 non-null   object
#  7   nationality   2250 non-null   object
#  8   team          1502 non-null   object
#  9   team_gender   1502 non-null   object
#  10  discipline    2271 non-null   object
#  11  event         2271 non-null   object
#  12  event_type    2271 non-null   object
#  13  url_event     2271 non-null   object
#  14  birth_date    2252 non-null   object
#  15  code          2271 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 284.0+ KB

# %%
medallists24_df.columns
# Out:
# Index(['medal_date', 'medal_type', 'medal_code', 'name', 'gender', 'country',
#        'country_code', 'nationality', 'team', 'team_gender', 'discipline',
#        'event', 'event_type', 'url_event', 'birth_date', 'code'],
#       dtype='object')

# %%
# search and find field for 'Code' column so I can find incorrect coding.

# medallists24_df[medallists24_df['code']=='SWAWTEAM2---CHN01']
medallists24_df.loc[654:670
                    ]
# Out:
#     medal_date    medal_type  medal_code                 name  gender  \
# 654  8/10/2024    Gold Medal           1                  NaN     NaN
# 655  8/10/2024  Silver Medal           2                  NaN     NaN
# 656  8/10/2024  Bronze Medal           3                  NaN     NaN
# 657  8/10/2024    Gold Medal           1   INGEBRIGTSEN Jakob    Male
# 658  8/10/2024  Silver Medal           2        KWEMOI Ronald    Male
# 659  8/10/2024  Bronze Medal           3         FISHER Grant    Male
# 660  8/10/2024    Gold Medal           1    WANYONYI Emmanuel    Male
# 661  8/10/2024  Silver Medal           2           AROP Marco    Male
# 662  8/10/2024  Bronze Medal           3       SEDJATI Djamel    Male
# 663  8/10/2024    Gold Medal           1          KERR Hamish    Male
# 664  8/10/2024  Silver Medal           2        McEWEN Shelby    Male
# 665  8/10/2024  Bronze Medal           3   BARSHIM Mutaz Essa    Male
# ...

# %%
# drop incorrect code rows
medallists24_df=medallists24_df.drop([654,655,656], axis=0)

# %%
# change code column to int64 so I can merge dataframe.
medallists24_df['code']=medallists24_df['code'].astype('Int64')

# %%
athletes24 = Path('../athletes.csv')

# %%
athletes24_df = pd.read_csv(athletes24, encoding="utf-8", low_memory = True)
athletes24_df.head()
# Out:
#       code               name     name_short            name_tv gender  \
# 0  1532872   ALEKSANYAN Artur   ALEKSANYAN A   Artur ALEKSANYAN   Male
# 1  1532873     AMOYAN Malkhas       AMOYAN M     Malkhas AMOYAN   Male
# 2  1532874    GALSTYAN Slavik     GALSTYAN S    Slavik GALSTYAN   Male
# 3  1532944  HARUTYUNYAN Arsen  HARUTYUNYAN A  Arsen HARUTYUNYAN   Male
# 4  1532945    TEVANYAN Vazgen     TEVANYAN V    Vazgen TEVANYAN   Male
#
#   function country_code  country country_full nationality  ...  \
# 0  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 1  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 2  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 3  Athlete          ARM  Armenia      Armenia     Armenia  ...
# 4  Athlete          ARM  Armenia      Armenia     Armenia  ...
#
#                                               family  \
# 0                          Father, Gevorg Aleksanyan
# ...

# %%
athletes24_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11110 entries, 0 to 11109
# Data columns (total 35 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   code                11110 non-null  int64
#  1   name                11110 non-null  object
#  2   name_short          11110 non-null  object
#  3   name_tv             11110 non-null  object
#  4   gender              11110 non-null  object
#  5   function            11110 non-null  object
#  6   country_code        11110 non-null  object
#  7   country             11110 non-null  object
#  8   country_full        11110 non-null  object
#  9   nationality         11091 non-null  object
#  10  nationality_full    11091 non-null  object
#  11  nationality_code    11091 non-null  object
#  12  height              11110 non-null  int64
#  13  weight              11092 non-null  float64
#  14  disciplines         11110 non-null  object
# ...

# %%
Athlete_medal24_df = pd.merge(athletes24_df,  
                      medallists24_df,  
                      on ='code', 
                      how ='left')
Athlete_medal24_df.head()
# Out:
#       code             name_x     name_short            name_tv gender_x  \
# 0  1532872   ALEKSANYAN Artur   ALEKSANYAN A   Artur ALEKSANYAN     Male
# 1  1532873     AMOYAN Malkhas       AMOYAN M     Malkhas AMOYAN     Male
# 2  1532874    GALSTYAN Slavik     GALSTYAN S    Slavik GALSTYAN     Male
# 3  1532944  HARUTYUNYAN Arsen  HARUTYUNYAN A  Arsen HARUTYUNYAN     Male
# 4  1532945    TEVANYAN Vazgen     TEVANYAN V    Vazgen TEVANYAN     Male
#
#   function country_code_x country_x country_full nationality_x  ... country_y  \
# 0  Athlete            ARM   Armenia      Armenia       Armenia  ...   Armenia
# 1  Athlete            ARM   Armenia      Armenia       Armenia  ...   Armenia
# 2  Athlete            ARM   Armenia      Armenia       Armenia  ...       NaN
# 3  Athlete            ARM   Armenia      Armenia       Armenia  ...       NaN
# 4  Athlete            ARM   Armenia      Armenia       Armenia  ...       NaN
#
# ...

# %%
Athlete_medal24_df.columns
# Out:
# Index(['code', 'name_x', 'name_short', 'name_tv', 'gender_x', 'function',
#        'country_code_x', 'country_x', 'country_full', 'nationality_x',
#        'nationality_full', 'nationality_code', 'height', 'weight',
#        'disciplines', 'events', 'birth_date_x', 'birth_place', 'birth_country',
#        'residence_place', 'residence_country', 'nickname', 'hobbies',
#        'occupation', 'education', 'family', 'lang', 'coach', 'reason', 'hero',
#        'influence', 'philosophy', 'sporting_relatives', 'ritual',
#        'other_sports', 'medal_date', 'medal_type', 'medal_code', 'name_y',
#        'gender_y', 'country_y', 'country_code_y', 'nationality_y', 'team',
#        'team_gender', 'discipline', 'event', 'event_type', 'url_event',
#        'birth_date_y'],
#       dtype='object')

# %%
Athlete_medal24_df = Athlete_medal24_df.drop(['name_x', 'name_short', 'name_tv', 'gender_x',
       'country_code_x', 'country_x', 'nationality_x',
       'nationality_full','birth_date_x', 'birth_place', 'birth_country',
       'residence_place', 'residence_country', 'nickname', 'hobbies',
       'occupation', 'education', 'family', 'lang', 'coach', 'reason', 'hero',
       'influence', 'philosophy', 'sporting_relatives', 'ritual',
       'other_sports','name_y',
       'gender_y', 'country_y', 'country_code_y', 'nationality_y',
       'team_gender', 'url_event',
       'birth_date_y' ], axis=1)
Athlete_medal24_df.head(15)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 Athlete_medal24_df = Athlete_medal24_df.drop(['name_x', 'name_short', 'name_tv', 'gender_x',
#       2        'country_code_x', 'country_x', 'nationality_x',
#       3        'nationality_full','birth_date_x', 'birth_place', 'birth_country',
#       4        'residence_place', 'residence_country', 'nickname', 'hobbies',
#       5        'occupation', 'education', 'family', 'lang', 'coach', 'reason', 'hero',
#       6        'influence', 'philosophy', 'sporting_relatives', 'ritual',
#       7        'other_sports','name_y',
#       8        'gender_y', 'country_y', 'country_code_y', 'nationality_y',
#       9        'team_gender', 'url_event',
#      10        'birth_date_y' ], axis=1)
#      11 Athlete_medal24_df.head(15)
#
# ...

# %%
Athlete_medal24_df.fillna(0)
# Out:
#           code function         country_full nationality_code  height  weight  \
# 0      1532872  Athlete              Armenia              ARM       0     0.0
# 1      1532873  Athlete              Armenia              ARM       0     0.0
# 2      1532874  Athlete              Armenia              ARM       0     0.0
# 3      1532944  Athlete              Armenia              ARM       0     0.0
# 4      1532945  Athlete              Armenia              ARM       0     0.0
# ...        ...      ...                  ...              ...     ...     ...
# 11347  4982175  Athlete  Trinidad and Tobago              TTO     177     0.0
# 11348  4982762  Athlete              Ukraine              UKR       0     0.0
# 11349  4983537  Athlete               Uganda              UGA     174     0.0
# 11350  4986655  Athlete    Equatorial Guinea              GEQ     165     0.0
# 11351  9460001  Athlete                Italy                0       0     0.0
#
# ...

# %%
Athlete_medal24_df['medal_type'] = Athlete_medal24_df['medal_type'].replace(to_replace=['Gold Medal', 'Silver Medal', 'Bronze Medal'], value = "1")

# %%
# Dropping additional rows
Athlete_medal24_df.drop(['disciplines', 'medal_code'], axis=1)
# Out:
#           code function         country_full nationality_code  height  weight  \
# 0      1532872  Athlete              Armenia              ARM       0     0.0
# 1      1532873  Athlete              Armenia              ARM       0     0.0
# 2      1532874  Athlete              Armenia              ARM       0     0.0
# 3      1532944  Athlete              Armenia              ARM       0     0.0
# 4      1532945  Athlete              Armenia              ARM       0     0.0
# ...        ...      ...                  ...              ...     ...     ...
# 11347  4982175  Athlete  Trinidad and Tobago              TTO     177     0.0
# 11348  4982762  Athlete              Ukraine              UKR       0     0.0
# 11349  4983537  Athlete               Uganda              UGA     174     0.0
# 11350  4986655  Athlete    Equatorial Guinea              GEQ     165     0.0
# 11351  9460001  Athlete                Italy              NaN       0     0.0
#
# ...

# %%
Athlete_medal24_df = Athlete_medal24_df.fillna(0)
Athlete_medal24_df
# Out:
#           code function         country_full nationality_code  height  weight  \
# 0      1532872  Athlete              Armenia              ARM       0     0.0
# 1      1532873  Athlete              Armenia              ARM       0     0.0
# 2      1532874  Athlete              Armenia              ARM       0     0.0
# 3      1532944  Athlete              Armenia              ARM       0     0.0
# 4      1532945  Athlete              Armenia              ARM       0     0.0
# ...        ...      ...                  ...              ...     ...     ...
# 11347  4982175  Athlete  Trinidad and Tobago              TTO     177     0.0
# 11348  4982762  Athlete              Ukraine              UKR       0     0.0
# 11349  4983537  Athlete               Uganda              UGA     174     0.0
# 11350  4986655  Athlete    Equatorial Guinea              GEQ     165     0.0
# 11351  9460001  Athlete                Italy                0       0     0.0
#
# ...

# %%
Athlete_medal24_df.to_csv('Athlete_medal24_df.csv')

# %%
# Run model
loaded_model = load("athlete medal.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 2
#       1 # Run model
# ----> 2 loaded_model = load("athlete medal.h5")
#
# NameError: name 'load' is not defined
