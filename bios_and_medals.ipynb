# %%
import pandas as pd
from pathlib import Path
import numpy as np

# %%
athlete_bios_path = "C:/Users/rache/gold/athlete_bios.csv"
medal_tally_path = "Olympic_Games_Medal_Tally.csv"
medallists_path = "C:/Users/rache/Going-For-Gold/medallists.csv"

# read the data
athlete_bios = pd.read_csv(athlete_bios_path)
medal_tally = pd.read_csv(medal_tally_path)
medallists = pd.read_csv(medallists_path)

# dataframes
athlete_bios = pd.DataFrame(athlete_bios)
medal_tally = pd.DataFrame(medal_tally)
medallists = pd.DataFrame(medallists)

# %%
# drop na values
medallists = medallists.dropna()

# %%
# drop na values
medal_tally = medal_tally.dropna()
medal_tally.head()
# Out:
#                 edition  edition_id  year        country country_noc  gold  \
# 0  1896 Summer Olympics           1  1896  United States         USA    11
# 1  1896 Summer Olympics           1  1896         Greece         GRE    10
# 2  1896 Summer Olympics           1  1896        Germany         GER     6
# 3  1896 Summer Olympics           1  1896         France         FRA     5
# 4  1896 Summer Olympics           1  1896  Great Britain         GBR     2
#
#    silver  bronze  total
# 0       7       2     20
# 1      18      19     47
# 2       5       2     13
# 3       4       2     11
# 4       3       2      7

# %%
# extract data for Summer Games 2000-present
medal_tally_summer = medal_tally.iloc[837:1343]

# %%
# show top ten countries by total medals
medal_tally_summer.sort_values(by=['total'], ascending=False)
medal_tally_summer
# Out:
#                    edition  edition_id  year                     country  \
# 837   2000 Summer Olympics          25  2000               United States
# 838   2000 Summer Olympics          25  2000          Russian Federation
# 839   2000 Summer Olympics          25  2000  People's Republic of China
# 840   2000 Summer Olympics          25  2000                   Australia
# 841   2000 Summer Olympics          25  2000                     Germany
# ...                    ...         ...   ...                         ...
# 1338  2020 Summer Olympics          61  2020                       Ghana
# 1339  2020 Summer Olympics          61  2020                     Grenada
# 1340  2020 Summer Olympics          61  2020                      Kuwait
# 1341  2020 Summer Olympics          61  2020         Republic of Moldova
# 1342  2020 Summer Olympics          61  2020        Syrian Arab Republic
#
#      country_noc  gold  silver  bronze  total
# ...

# %%
# export to csv
medal_tally_summer.to_csv("medal_tally_summer.csv")

# %%
athlete_bios.head()
# Out:
#    Unnamed: 0  athlete_id                     name   sex       born  height  \
# 0         120       57070        Mohammad Halilula  Male  14-Feb-52     163
# 1         888       57089        Khojawahid Zahedi  Male   5-Jun-60     178
# 2        3168       57072  Mohammad Ibrahim Kederi  Male  10-Aug-40     166
# 3       11273       57074       Amir Jan Khalunder  Male  20-Nov-24     166
# 4       17612       57071          Sakhidad Hamidi  Male  10-Oct-52     170
#
#   weight       country country_noc
# 0     57   Afghanistan         AFG
# 1     74   Afghanistan         AFG
# 2     62   Afghanistan         AFG
# 3     66   Afghanistan         AFG
# 4     68   Afghanistan         AFG

# %%
athlete_totals = athlete_bios['country_noc'].value_counts()
athlete_totals
# Out:
# country_noc
# USA    7655
# CAN    4028
# FRA    3777
# GBR    3760
# JPN    3741
#        ...
# IFR       2
# YMD       2
# UAR       1
# SAA       1
# SSD       1
# Name: count, Length: 228, dtype: int64

# %%
athlete_totals.median()
# Out:
# 95.5
